# %% [markdown]
# # Exploratory Analysis
#
# We'll start by importing the answers to the questionnaire as a CSV file in a pandas DataFrame, and map the answers in a readable way.

# %%
answers_file = 'answers.csv'
questions_map = 'questions_map.txt'

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv(answers_file, delimiter=";")
print("Dataframe size: ", df.shape)
df = df.dropna()
print("Purged dataframe size: ", df.shape)
df.head()
# Out:
# Dataframe size:  (74, 37)
# Purged dataframe size:  (70, 37)
#           Età      Titolo di studio Genere Hai un profilo Instagram?  \
# 3  19-30 anni               Diploma      M                        Si
# 4  19-30 anni  Laurea Specialistica      F                        Si
# 5  19-30 anni      Laurea Triennale      F                        Si
# 6  19-30 anni               Diploma      F                        Si
# 7  19-30 anni      Laurea Triennale      F                        Si
#
#   Da quanto tempo sei iscritto ad Instagram?  \
# 3                        Tra 6 mesi e 1 anno
# 4                           Da più di 3 anni
# 5                        Tra 1 anno e 3 anni
# 6                        Tra 6 mesi e 1 anno
# 7                             Meno di 6 mesi
#
#   Quanto tempo pensi di trascorrere su Instagram, in media, al giorno?  \
# 3                                      Tra 1 e 2 ore
# 4                                       Più di 4 ore
# 5                                      Tra 1 e 2 ore
# 6                                      Tra 1 e 2 ore
# 7                                      Tra 1 e 2 ore
#
#   Seguire persone che conosco Caricare foto e/o video  \
# 3                  4 (spesso)           2 (raramente)
# 4                  4 (spesso)              4 (spesso)
# 5                  4 (spesso)           2 (raramente)
# 6           3 (qualche volta)           2 (raramente)
# 7                  4 (spesso)       3 (qualche volta)
#
#   Seguire Influencer o blogger Seguire pagine di brand o aziende  \
# 3                2 (raramente)                 3 (qualche volta)
# 4            3 (qualche volta)                 3 (qualche volta)
# 5                   4 (spesso)                        4 (spesso)
# 6                   4 (spesso)                           1 (mai)
# 7                2 (raramente)                     2 (raramente)
#
#                                               ...                                              \
# 3                                             ...
# 4                                             ...
# 5                                             ...
# 6                                             ...
# 7                                             ...
#
#   Penso che gli influencer siano sinceri  \
# 3                                      3
# 4                                      3
# 5                                      3
# 6                                      2
# 7                                      3
#
#   Penso che gli influencer abbiano una reale esperienza dei prodotti che sponsorizzano  \
# 3                                                  2
# 4                                                  3
# 5                                                  3
# 6                                                  3
# 7                                 4 (Decisamente si)
#
#   Visito la pagina del brand o del prodotto sponsorizzato  \
# 3                                  3 (qualche volta)
# 4                                  3 (qualche volta)
# 5                                      2 (raramente)
# 6                                            1 (mai)
# 7                                            1 (mai)
#
#   Interagisco (like o commenti) nella pagina del brand o prodotto sponsorizzato  \
# 3                                      2 (raramente)
# 4                                  3 (qualche volta)
# 5                                      2 (raramente)
# 6                                            1 (mai)
# 7                                      2 (raramente)
#
#   Condivido informazioni sul brand o prodotto sponsorizzato  \
# 3                                      2 (raramente)
# 4                                         4 (spesso)
# 5                                      2 (raramente)
# 6                                            1 (mai)
# 7                                            1 (mai)
#
#   Cerco informazioni sul prodotto tramite altri canali  \
# 3                                         4 (spesso)
# 4                                         4 (spesso)
# 5                                      2 (raramente)
# 6                                            1 (mai)
# 7                                  3 (qualche volta)
#
#   Utilizzo instagram per comunicare direttamente con il brand  \
# 3                                      2 (raramente)
# 4                                  3 (qualche volta)
# 5                                            1 (mai)
# 6                                            1 (mai)
# 7                                            1 (mai)
#
#   Ho comprato uno o più prodotti sponsorizzati da un influencer su instagram  \
# 3                                  3 (qualche volta)
# 4                                         4 (spesso)
# 5                                      2 (raramente)
# 6                                      2 (raramente)
# 7                                  3 (qualche volta)
#
#   Ho consigliato ad amici e conoscenti di acquistare il prodotto sponsorizato  \
# 3                                  3 (qualche volta)
# 4                                  3 (qualche volta)
# 5                                            1 (mai)
# 6                                            1 (mai)
# 7                                      2 (raramente)
#
#   Uso la mia pagina instagram per mostrare il prodotto acquistato o l'esperienza con il brand
# 3                                      2 (raramente)
# 4                                      2 (raramente)
# 5                                            1 (mai)
# 6                                            1 (mai)
# 7                                            1 (mai)
#
# [5 rows x 37 columns]

# %%
mapping = open(questions_map, 'r')
questions = mapping.read().split(";")
mapping.close()
mapping = {before: after for before, after in zip(df.columns.values, questions)}
for before, after in mapping.items():
    print(before, "->", after)
# Out:
# Età -> demo-special-age
# Titolo di studio -> demo-special-studies
# Genere -> demo-cat-gender
# Hai un profilo Instagram? -> demo-num-have_ig
# Da quanto tempo sei iscritto ad Instagram? -> demo-special-ig_since
# Quanto tempo pensi di trascorrere su Instagram, in media, al giorno? -> demo-special-ig_time_daily
# Seguire persone che conosco -> act-num-follow_friends
# Caricare foto e/o video -> act-num-share_stuff
# Seguire Influencer o blogger -> act-num-follow_infl
# Seguire pagine di brand o aziende -> act-num-follow_brands
# Seguire VIP o persone famose -> act-num-follow_vips
# Scambiare opinioni e/o consigli su prodotti e brand -> act-num-share_brands
# Chattare -> act-num-chat
# Segui uno o più Influencer su Instagram? -> bool-does_follow_infl
# Come sei venuto a conoscenza delle pagine degli Influencer ch segui? (Max. 2 risposte) -> mul-how_discovered_infl
# A quali settori diresti appartengono la maggior parte degli influencer che segui? (Max. 2 risposte) -> mul-infl_verticals
# Quanti follower hanno in media gli Influencer che segui con più costanza? (Max. 2 risposte) -> special-infl_followers
# Per la personalitÖ ed il carattere dell'influencer -> because-num-personality
# Per le caratteristiche fisiche dell'influencer -> because-num-body
# Per l'interesse verso I temi trattati nei contenuti pubblicati -> because-num-topics
# Perchä ha un grande numero di follower -> because-num-many_followers
# Perchä I miei amici e conoscenti lo seguono -> because-num-everybody_does
# Per ricevere consigli e suggerimenti su prodotti e brand -> because-num-brand_tips
# Mi fido degli influencer che seguo -> do-num-trust
# Seguo I consigli che gli influencer danno anche nella vita di tutti I giorni -> do-num-follow_advices
# Consiglio ad amici e conoscenti di seguire gli infleuncer che seguo io -> do-num-referral
# penso che gli influencer siano esperti nel loro campo -> do-num-think_infl_experts
# Penso che gli influencer siano sinceri -> do-num-think_trushworthy
# Penso che gli influencer abbiano una reale esperienza dei prodotti che sponsorizzano -> do-num-think_really_tried
# Visito la pagina del brand o del prodotto sponsorizzato -> num-visit_sponsored_page
# Interagisco (like o commenti) nella pagina del brand o prodotto sponsorizzato -> num-interact_w_sponsored_brand
# Condivido informazioni sul brand o prodotto sponsorizzato -> num-do_referral_brand
# Cerco informazioni sul prodotto tramite altri canali -> num-cross_information
# Utilizzo instagram per comunicare direttamente con il brand -> num-direct_brand_communication
# Ho comprato uno o più prodotti sponsorizzati da un influencer su instagram -> num-did_buy_via_infl
# Ho consigliato ad amici e conoscenti di acquistare il prodotto sponsorizato -> num-did_referred_sponsored_item
# Uso la mia pagina instagram per mostrare il prodotto acquistato o l'esperienza con il brand -> num-wannabe_infl

# %%
df = df.rename(columns=mapping)
df.head()
# Out:
#   demo-special-age  demo-special-studies demo-cat-gender demo-num-have_ig  \
# 3       19-30 anni               Diploma               M               Si
# 4       19-30 anni  Laurea Specialistica               F               Si
# 5       19-30 anni      Laurea Triennale               F               Si
# 6       19-30 anni               Diploma               F               Si
# 7       19-30 anni      Laurea Triennale               F               Si
#
#   demo-special-ig_since demo-special-ig_time_daily act-num-follow_friends  \
# 3   Tra 6 mesi e 1 anno              Tra 1 e 2 ore             4 (spesso)
# 4      Da più di 3 anni               Più di 4 ore             4 (spesso)
# 5   Tra 1 anno e 3 anni              Tra 1 e 2 ore             4 (spesso)
# 6   Tra 6 mesi e 1 anno              Tra 1 e 2 ore      3 (qualche volta)
# 7        Meno di 6 mesi              Tra 1 e 2 ore             4 (spesso)
#
#   act-num-share_stuff act-num-follow_infl act-num-follow_brands  \
# 3       2 (raramente)       2 (raramente)     3 (qualche volta)
# 4          4 (spesso)   3 (qualche volta)     3 (qualche volta)
# 5       2 (raramente)          4 (spesso)            4 (spesso)
# 6       2 (raramente)          4 (spesso)               1 (mai)
# 7   3 (qualche volta)       2 (raramente)         2 (raramente)
#
#         ...        do-num-think_trushworthy do-num-think_really_tried  \
# 3       ...                               3                         2
# 4       ...                               3                         3
# 5       ...                               3                         3
# 6       ...                               2                         3
# 7       ...                               3        4 (Decisamente si)
#
#   num-visit_sponsored_page num-interact_w_sponsored_brand  \
# 3        3 (qualche volta)                  2 (raramente)
# 4        3 (qualche volta)              3 (qualche volta)
# 5            2 (raramente)                  2 (raramente)
# 6                  1 (mai)                        1 (mai)
# 7                  1 (mai)                  2 (raramente)
#
#   num-do_referral_brand num-cross_information num-direct_brand_communication  \
# 3         2 (raramente)            4 (spesso)                  2 (raramente)
# 4            4 (spesso)            4 (spesso)              3 (qualche volta)
# 5         2 (raramente)         2 (raramente)                        1 (mai)
# 6               1 (mai)               1 (mai)                        1 (mai)
# 7               1 (mai)     3 (qualche volta)                        1 (mai)
#
#   num-did_buy_via_infl num-did_referred_sponsored_item num-wannabe_infl
# 3    3 (qualche volta)               3 (qualche volta)    2 (raramente)
# 4           4 (spesso)               3 (qualche volta)    2 (raramente)
# 5        2 (raramente)                         1 (mai)          1 (mai)
# 6        2 (raramente)                         1 (mai)          1 (mai)
# 7    3 (qualche volta)                   2 (raramente)          1 (mai)
#
# [5 rows x 37 columns]

# %% [markdown]
# Let's take a look at how many respondents do we have:

# %%
print("Respondents: ", df.shape[0])
print("Questions: ", df.shape[1])
# Out:
# Respondents:  70
# Questions:  37

# %% [markdown]
# Do everybody have Instagram? If they do, drop that specific question:

# %%
if df['demo-num-have_ig'].value_counts().shape[0] == 1:
    df = df.drop(columns=['demo-num-have_ig'])

# %% [markdown]
# Starting analysis: most frequent demographics about respondents.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-white')

demo_df = df[[c for c in df.columns.values if c[:5] == 'demo-']]
print("Demographics features: ", demo_df.shape[1])

rows = int(demo_df.shape[1]/3)+(demo_df.shape[1]%3>0)
cols = 3
fig, ax = plt.subplots(rows, cols, figsize=(15,15))
print("Plot size: ", rows, ":", cols)
answer = 0
for row in range(rows):
    for col in range(cols):
        if answer == demo_df.shape[1]:
            break
        sns.countplot(demo_df[demo_df.columns.values[answer]], ax=ax[row, col])
        plt.setp(ax[row, col].get_xticklabels(), rotation=30, horizontalalignment='right')
        answer += 1
# Out:
# Demographics features:  5
# Plot size:  2 : 3

# %% [markdown]
# Now, we have to map every question from qualitative answers to quantitative answers:

# %%
# First, the categorical answers

from sklearn import preprocessing
les = {}

for c in [c for c in df.columns.values if 'cat-' in c]:
    le = preprocessing.LabelEncoder()
    le.fit(df[c].values)
    df[c] = le.transform(df[c].values)
    les[c] = le
    print("Column {} -> {}".format(c, df[c].values[:5]))
# Out:
# Column demo-cat-gender -> [1 0 0 0 0]

# %%
# Features that are numerical, but needs to be handled
for c in [c for c in df.columns.values if 'num-' in c]:
    cc = df[c].astype(str).str.extract('([0-9]{1})', expand=False).str.strip().astype(int)
    df[c] = cc
    print(c, "->", cc.mean())
# Out:
# act-num-follow_friends -> 3.642857142857143
# act-num-share_stuff -> 2.857142857142857
# act-num-follow_infl -> 3.3
# act-num-follow_brands -> 2.8285714285714287
# act-num-follow_vips -> 3.2285714285714286
# act-num-share_brands -> 1.7285714285714286
# act-num-chat -> 2.857142857142857
# because-num-personality -> 3.3714285714285714
# because-num-body -> 2.257142857142857
# because-num-topics -> 3.5142857142857142
# because-num-many_followers -> 1.4857142857142858
# because-num-everybody_does -> 1.5714285714285714
# because-num-brand_tips -> 2.7142857142857144
# do-num-trust -> 3.1857142857142855
# do-num-follow_advices -> 2.3857142857142857
# do-num-referral -> 2.4285714285714284
# do-num-think_infl_experts -> 2.7857142857142856
# do-num-think_trushworthy -> 2.4
# do-num-think_really_tried -> 2.6142857142857143
# num-visit_sponsored_page -> 2.4714285714285715
# num-interact_w_sponsored_brand -> 1.9714285714285715
# num-do_referral_brand -> 1.5571428571428572
# num-cross_information -> 2.642857142857143
# num-direct_brand_communication -> 1.4285714285714286
# num-did_buy_via_infl -> 1.8142857142857143
# num-did_referred_sponsored_item -> 1.6571428571428573
# num-wannabe_infl -> 1.2714285714285714

# %%
# Let's plot numerical data, to get a glimpse of how things are going

num_df = df[[c for c in df.columns.values if 'num-' in c]]
num_df.describe()
# Out:
#        act-num-follow_friends  act-num-share_stuff  act-num-follow_infl  \
# count               70.000000            70.000000            70.000000
# mean                 3.642857             2.857143             3.300000
# std                  0.565576             0.747667             0.804876
# min                  2.000000             2.000000             1.000000
# 25%                  3.000000             2.000000             3.000000
# 50%                  4.000000             3.000000             3.500000
# 75%                  4.000000             3.000000             4.000000
# max                  4.000000             4.000000             4.000000
#
#        act-num-follow_brands  act-num-follow_vips  act-num-share_brands  \
# count              70.000000            70.000000             70.000000
# mean                2.828571             3.228571              1.728571
# std                 0.916380             0.801655              0.849918
# min                 1.000000             1.000000              1.000000
# 25%                 2.000000             3.000000              1.000000
# 50%                 3.000000             3.000000              2.000000
# 75%                 3.750000             4.000000              2.000000
# max                 4.000000             4.000000              4.000000
#
#        act-num-chat  because-num-personality  because-num-body  \
# count     70.000000                70.000000         70.000000
# mean       2.857143                 3.371429          2.257143
# std        1.039589                 0.783367          1.085954
# min        1.000000                 1.000000          1.000000
# 25%        2.000000                 3.000000          1.000000
# 50%        3.000000                 4.000000          2.000000
# 75%        4.000000                 4.000000          3.000000
# max        4.000000                 4.000000          4.000000
#
#        because-num-topics        ...         do-num-think_trushworthy  \
# count           70.000000        ...                        70.000000
# mean             3.514286        ...                         2.400000
# std              0.607748        ...                         0.623222
# min              2.000000        ...                         1.000000
# 25%              3.000000        ...                         2.000000
# 50%              4.000000        ...                         2.000000
# 75%              4.000000        ...                         3.000000
# max              4.000000        ...                         4.000000
#
#        do-num-think_really_tried  num-visit_sponsored_page  \
# count                  70.000000                 70.000000
# mean                    2.614286                  2.471429
# std                     0.766941                  0.846501
# min                     1.000000                  1.000000
# 25%                     2.000000                  2.000000
# 50%                     3.000000                  3.000000
# 75%                     3.000000                  3.000000
# max                     4.000000                  4.000000
#
#        num-interact_w_sponsored_brand  num-do_referral_brand  \
# count                       70.000000              70.000000
# mean                         1.971429               1.557143
# std                          0.833561               0.734960
# min                          1.000000               1.000000
# 25%                          1.000000               1.000000
# 50%                          2.000000               1.000000
# 75%                          3.000000               2.000000
# max                          4.000000               4.000000
#
#        num-cross_information  num-direct_brand_communication  \
# count              70.000000                       70.000000
# mean                2.642857                        1.428571
# std                 0.948465                        0.627196
# min                 1.000000                        1.000000
# 25%                 2.000000                        1.000000
# 50%                 3.000000                        1.000000
# 75%                 3.000000                        2.000000
# max                 4.000000                        3.000000
#
#        num-did_buy_via_infl  num-did_referred_sponsored_item  num-wannabe_infl
# count             70.000000                        70.000000         70.000000
# mean               1.814286                         1.657143          1.271429
# std                0.785611                         0.778064          0.611992
# min                1.000000                         1.000000          1.000000
# 25%                1.000000                         1.000000          1.000000
# 50%                2.000000                         1.000000          1.000000
# 75%                2.000000                         2.000000          1.000000
# max                4.000000                         3.000000          4.000000
#
# [8 rows x 27 columns]

# %%
# Then, special cases, that needs to be taken into ad-hoc consideration
# Features that are numerical, but needs to be handled
for c in [c for c in df.columns.values if 'special-' in c]:
    print(c, "->", df[c].unique())
# Out:
# demo-special-age -> ['19-30 anni' '14-18 anni']
# demo-special-studies -> ['Diploma' 'Laurea Specialistica' 'Laurea Triennale' 'Licenza Media'
#  'Medie' 'Studente']
# demo-special-ig_since -> ['Tra 6 mesi e 1 anno' 'Da più di 3 anni' 'Tra 1 anno e 3 anni'
#  'Meno di 6 mesi']
# demo-special-ig_time_daily -> ['Tra 1 e 2 ore' 'Più di 4 ore' 'Tra 2 e 4 ore' 'Meno di 1 ora']
# special-infl_followers -> ['da 100.000 a 500.000, da 500.000 a 1 Milione'
#  'da 3.000 a 20.000, da 100.000 a 500.000'
#  'da 100.000 a 500.000, da 500.000 a 1 Milione, da 1 Milione in su'
#  'da 20.000 a 100.000, da 100.000 a 500.000' 'da 1 Milione in su'
#  'da 20.000 a 100.000' 'da 500.000 a 1 Milione, da 1 Milione in su'
#  'da 3.000 a 20.000, da 20.000 a 100.000'
#  'da 100.000 a 500.000, da 1 Milione in su'
#  'da 3.000 a 20.000, da 1 Milione in su' 'da 500.000 a 1 Milione'
#  'da 3.000 a 20.000' 'da 3.000 a 20.000, da 500.000 a 1 Milione'
#  'da 20.000 a 100.000, da 1 Milione in su'
#  'da 3.000 a 20.000, da 100.000 a 500.000, da 1 Milione in su'
#  'da 100.000 a 500.000' 'da 20.000 a 100.000, da 500.000 a 1 Milione']

# %%
import re

def map_followers(s):
    s = s.replace("1 Milione", "1000000").replace(".", "")
    p = re.compile("([0-9]+)")
    rng = [int(x) for x in p.findall(s)]
    return int(sum(rng)/len(rng))

def map_age(s):
    if '14' in s:
        return 0
    if '19' in s:
        return 1
    print(s)
    return -1

def map_ig_since(s):
    if 'Meno di 6' in s:
        return 0
    if 'Tra 6' in s:
        return 1
    if 'Tra 1' in s:
        return 2
    if 'Da più di 3' in s:
        return 3
    print(s)
    return -1

def map_ig_time(s):
    if 'Meno di' in s:
        return 0
    if 'Tra 1' in s:
        return 1
    if 'Tra 2' in s:
        return 2
    if 'Più di' in s:
        return 3
    print(s)
    return -1

def map_studies(s):
    if (s == "Medie") or (s == "Studente"):
        return 0
    if s == "Licenza Media":
        return 1
    if s == "Diploma":
        return 2
    if s == "Laurea Triennale":
        return 3
    if s == "Laurea Specialistica":
        return 4
    print(s)
    return -1

def map_infl(s):
    if "N" in s:
        return 0
    if "S" in s:
        return 1
    print(s)
    return -1

mapping_functions = {
    'demo-special-studies': map_studies,
    'demo-special-ig_time_daily': map_ig_time,
    'demo-special-ig_since': map_ig_since,
    'demo-special-age': map_age,
    'special-infl_followers': map_followers,
    'bool-does_follow_infl': map_infl,
}

# %%
for key, function in mapping_functions.items():
    df[key] = df[key].apply(function).astype(int)
    print("{} 's unmapped items: ".format(key), df[df[key] == -1].shape[0])
# Out:
# demo-special-studies 's unmapped items:  0
# demo-special-ig_time_daily 's unmapped items:  0
# demo-special-ig_since 's unmapped items:  0
# demo-special-age 's unmapped items:  0
# special-infl_followers 's unmapped items:  0
# bool-does_follow_infl 's unmapped items:  0

# %%
df.dtypes
# Out:
# demo-special-age                    int64
# demo-special-studies                int64
# demo-cat-gender                     int64
# demo-special-ig_since               int64
# demo-special-ig_time_daily          int64
# act-num-follow_friends              int64
# act-num-share_stuff                 int64
# act-num-follow_infl                 int64
# act-num-follow_brands               int64
# act-num-follow_vips                 int64
# act-num-share_brands                int64
# act-num-chat                        int64
# bool-does_follow_infl               int64
# mul-how_discovered_infl            object
# mul-infl_verticals                 object
# special-infl_followers              int64
# because-num-personality             int64
# because-num-body                    int64
# because-num-topics                  int64
# because-num-many_followers          int64
# because-num-everybody_does          int64
# because-num-brand_tips              int64
# do-num-trust                        int64
# do-num-follow_advices               int64
# do-num-referral                     int64
# do-num-think_infl_experts           int64
# do-num-think_trushworthy            int64
# do-num-think_really_tried           int64
# num-visit_sponsored_page            int64
# num-interact_w_sponsored_brand      int64
# num-do_referral_brand               int64
# num-cross_information               int64
# num-direct_brand_communication      int64
# num-did_buy_via_infl                int64
# num-did_referred_sponsored_item     int64
# num-wannabe_infl                    int64
# dtype: object

# %%
# Let's ignore complex mutiple answers for the time being
df_min = df[[c for c in df.columns.values if 'mul-' not in c]]
df_min = df_min.rename(columns={c: c.split("-")[-1] for c in df_min.columns.values})

# %%
# Let's define an entropy formula

import numpy as np
from math import log, e

def entropy(labels, base=None):
    """ Computes entropy of label distribution. """
    n_labels = len(labels)
    if n_labels <= 1:
        return 0
    value, counts = np.unique(labels, return_counts=True)
    probs = counts / n_labels
    n_classes = np.count_nonzero(probs)
    if n_classes <= 1:
        return 0
    ent = 0.
    # Compute entropy
    base = e if base is None else base
    for i in probs:
        ent -= i * log(i, base)
    return ent

# %%
means = {}
stds = {}
ents = {}

for c in df_min.columns.values:
    cc = df_min[c]
    means[c] = cc.mean()
    stds[c] = cc.std()
    ents[c] = entropy(cc.values)
    
ents_srt = sorted(ents.items(), key=lambda x: x[1])
print("Least 5 controversial questions:")
for ex in ents_srt[:5]:
    print("\t{} -> {}".format(ex[0], ex[1]))
    
print("Top 5 controversial questions:")
for ex in ents_srt[-5:]:
    print("\t{} -> {}".format(ex[0], ex[1]))
# Out:
# Least 5 controversial questions:
# 	does_follow_infl -> 0
# 	trust -> 0.47994861471265415
# 	age -> 0.5195798391305154
# 	gender -> 0.5720648448722231
# 	wannabe_infl -> 0.6521897780905997
# Top 5 controversial questions:
# 	chat -> 1.329285186729287
# 	body -> 1.3306541070952487
# 	brand_tips -> 1.3413111842956573
# 	studies -> 1.4204273840693176
# 	infl_followers -> 2.4364966411514373

# %%
# Let's standardize the columns
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_min[df_min.columns] = scaler.fit_transform(df_min[df_min.columns])

# Plot the whole thing, ordered by entropy
rows = int(df_min.shape[1]/3)+(df_min.shape[1]%3>0)
cols = 3
fig, ax = plt.subplots(rows, cols, figsize=(15,30))
answer = 0
for row in range(rows):
    for col in range(cols):
        if answer == df_min.shape[1]:
            break
        feature_name = ents_srt[answer][0]
        cc = df_min[feature_name]
        sns.distplot(cc, ax=ax[row, col])
        ax[row, col].text(0.5, 0.5, str(round(means[feature_name], 2)) + \
                                    " ± " + str(round(stds[feature_name], 2)) + \
                                    "\n({})".format(round(ents[feature_name], 2)), 
                          fontsize=13, 
                          horizontalalignment='center', 
                          verticalalignment='center', 
                          transform=ax[row, col].transAxes,
                          bbox=dict(facecolor='red', alpha=0.5))
        answer += 1
        
fig.tight_layout()

# %% [markdown]
# Which are the most controversial questions? Which are the closest to the extremes?

# %%
# Out:
# Least 5 controversial questions:
# 	does_follow_infl -> 0
# 	trust -> 0.47994861471265415
# 	age -> 0.5195798391305154
# 	gender -> 0.5720648448722231
# 	wannabe_infl -> 0.6521897780905997
# Top 5 controversial questions:
# 	chat -> 1.329285186729287
# 	body -> 1.3306541070952487
# 	brand_tips -> 1.3413111842956573
# 	studies -> 1.4204273840693176
# 	infl_followers -> 2.4364966411514373
