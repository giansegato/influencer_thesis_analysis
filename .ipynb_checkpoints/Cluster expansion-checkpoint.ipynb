# %%
import imp
import clustering
imp.reload(clustering)
# Out:
# <module 'clustering' from '/Users/gianluca/Developer/workspace/Python/tesi_emma/clustering.py'>

# %%
clustering.plot_cluster(subset=['travel', 'tech', 'fashion', 'fitness', 'food',
                        'age', 'studies', 'gender', 'ig_since', 'ig_time_daily'],
                        clusters = 7)
# Out:
# Dataframe size:  (3330, 37)
# Purged dataframe size:  (3210, 37)
# Dropping demo-num-have_ig because it's constant
# Dropping bool-does_follow_infl because it's constant
#
# ****
# Cluster analysis using the following subset:  ['travel', 'tech', 'fashion', 'fitness', 'food', 'age', 'studies', 'gender', 'ig_since', 'ig_time_daily']
# Number of clusters =  7
# ****
#
# Matrix size:  (3210, 10)
# Variance explained in 3 dimensions:  0.7618654767000248
# 0.75 cutoff ->  3
# 0.90 cutoff ->  5
# Average inertia: 102.01016849856101

# %%
clustering.plot_cluster(subset=['travel', 'tech', 'fashion', 'fitness', 'food',
                        'age', 'studies', 'gender', 'ig_since', 'ig_time_daily',
                        'visit_sponsored_page', 'interact_w_sponsored_brand',
                        'do_referral_brand', 'cross_information', 'direct_brand_communication',
                        'did_buy_via_infl', 'did_referred_sponsored_item', 'wannabe_infl'],
                        clusters = 3)
# Out:
# Dataframe size:  (3330, 37)
# Purged dataframe size:  (3210, 37)
# Dropping demo-num-have_ig because it's constant
# Dropping bool-does_follow_infl because it's constant
#
# ****
# Cluster analysis using the following subset:  ['travel', 'tech', 'fashion', 'fitness', 'food', 'age', 'studies', 'gender', 'ig_since', 'ig_time_daily', 'visit_sponsored_page', 'interact_w_sponsored_brand', 'do_referral_brand', 'cross_information', 'direct_brand_communication', 'did_buy_via_infl', 'did_referred_sponsored_item', 'wannabe_infl']
# Number of clusters =  3
# ****
#
# Matrix size:  (3210, 18)
# Variance explained in 3 dimensions:  0.5680688273165032
# 0.75 cutoff ->  6
# 0.90 cutoff ->  11
# Average inertia: 346.76333029597725

# %%
clustering.plot_cluster(subset=['travel', 'tech', 'fashion', 'fitness', 'food',
                        'age', 'studies', 'gender', 'ig_since', 'ig_time_daily',
                        'visit_sponsored_page', 'interact_w_sponsored_brand',
                        'do_referral_brand', 'cross_information', 'direct_brand_communication',
                        'did_buy_via_infl', 'did_referred_sponsored_item', 'wannabe_infl',
                        'trust', 'follow_advices', 'referral', 'think_infl_experts', 'think_trushworthy',
                        'think_really_tried'],
                        clusters = 3)
# Out:
# Dataframe size:  (3330, 37)
# Purged dataframe size:  (3210, 37)
# Dropping demo-num-have_ig because it's constant
# Dropping bool-does_follow_infl because it's constant
#
# ****
# Cluster analysis using the following subset:  ['travel', 'tech', 'fashion', 'fitness', 'food', 'age', 'studies', 'gender', 'ig_since', 'ig_time_daily', 'visit_sponsored_page', 'interact_w_sponsored_brand', 'do_referral_brand', 'cross_information', 'direct_brand_communication', 'did_buy_via_infl', 'did_referred_sponsored_item', 'wannabe_infl', 'trust', 'follow_advices', 'referral', 'think_infl_experts', 'think_trushworthy', 'think_really_tried']
# Number of clusters =  3
# ****
#
# Matrix size:  (3210, 24)
# Variance explained in 3 dimensions:  0.4879963666255662
# 0.75 cutoff ->  9
# 0.90 cutoff ->  15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7079006419cf> in <module>()
# ...
